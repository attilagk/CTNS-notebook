# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
scores = pd.read_csv(fpath, header=[0, 1])
scores
# Out:
#      Unnamed: 0_level_0 drug information                                      \
#      Unnamed: 0_level_1        drug_name max_phase          indication_class
# 0         CHEMBL1770916     NIROGACESTAT         3                       NaN
# 1          CHEMBL520733     SEMAGACESTAT         3                       NaN
# 2          CHEMBL360328       LORCASERIN         4                       NaN
# 3           CHEMBL99946  LEVOMILNACIPRAN         4                       NaN
# 4           CHEMBL14370       REBOXETINE         4                       NaN
# ...                 ...              ...       ...                       ...
# 2408       CHEMBL236593      TELCAGEPANT         3                       NaN
# 2409      CHEMBL3716057       GEFAPIXANT         3                       NaN
# 2410          CHEMBL770       TOLAZOLINE         4  Vasodilator (peripheral)
# 2411      CHEMBL3991065        ATOGEPANT         3                       NaN
# ...

# %%
fig, ax = plt.subplots()
ax.hist(scores.loc[:, ('knowledge', 'p')])
#ax.set_xscale('log')
# Out:
# (array([362., 150., 157., 199., 196., 277., 262., 261., 288., 261.]),
#  array([6.49076193e-09, 9.99991543e-02, 1.99998302e-01, 2.99997450e-01,
#         3.99996598e-01, 4.99995745e-01, 5.99994893e-01, 6.99994041e-01,
#         7.99993189e-01, 8.99992336e-01, 9.99991484e-01]),
#  <BarContainer object of 10 artists>)

# %%
# %connect_info
# Out:
# {
#   "shell_port": 49374,
#   "iopub_port": 49375,
#   "stdin_port": 49376,
#   "control_port": 49378,
#   "hb_port": 49377,
#   "ip": "127.0.0.1",
#   "key": "73f91073-b9dd15c1ded1b14ed9179071",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": ""
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-cee5e4a6-7258-4be8-9fa7-6ea2830bbd58.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.

# %%
who
# Out:
# fpath	 pd	 scores
