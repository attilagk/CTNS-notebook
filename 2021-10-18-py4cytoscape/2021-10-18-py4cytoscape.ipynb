# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
import pandas as pd
import matplotlib.pyplot as plt
from toolbox import wrappers
from toolbox import network_utilities
import repos_tools
import attila_utils
# Out:
# GenRev not found, steiner wont work
# Import error: Negex. Using keyword matching instead
# Import error: Funcassociate. Make sure that funcassociate is in toolbox!

# %%
import py4cytoscape as p4c
p4c.cytoscape_ping()
p4c.cytoscape_version_info()
# Out:
# You are connected to Cytoscape!
# {'apiVersion': 'v1',
#  'cytoscapeVersion': '3.8.2',
#  'automationAPIVersion': '1.3.0',
#  'py4cytoscapeVersion': '0.0.11'}

# %%
nodes = pd.DataFrame(data={'id': ["node 0","node 1","node 2","node 3"], 'group': ["A","A","B","B"], 'score': [20,10,15,5]})
edges = pd.DataFrame(data={'source': ["node 0","node 0","node 0","node 2"], 'target': ["node 1","node 2","node 3","node 3"], 'interaction': ["inhibits","interacts","activates","interacts"], 'weight': [5.1,3.0,5.2,9.9]})
p4c.create_network_from_data_frames(nodes, edges, title="my first network", collection="DataFrame Example")
# Out:
# Applying default style...
# Applying preferred layout
# {'networkSUID': 533665}

# %%
# %%bash
# if test ! -d named-figure; then
#     mkdir named-figure
# fi

# %%
p4c.notebook_export_show_image(filename='default', type='PNG')

# %%
repr(p4c.get_visual_style_names())
# Out:
# "['Marquee', 'default black', 'Metallic', 'Sample1', 'Solid', 'galFiltered Style', 'Directed', 'BioPAX', 'Custom Graphics Style', 'Big Labels', 'default', 'Universe', 'Nested Network Style', 'Minimal', 'Box', 'Ripple', 'BioPAX_SIF']"

# %%
p4c.set_visual_style('Universe')
p4c.notebook_export_show_image(filename='Universe')

# %%
id_mapping_file = '../../resources/PPI/geneid_to_symbol.txt'
network = wrappers.get_network('../../resources/PPI/Cheng2019/network.sif', only_lcc = True)
id_symbol = pd.read_csv(id_mapping_file, sep='\t', index_col='GeneID')
id_symbol = id_symbol.set_index(id_symbol.index.astype('str'))

# %%
p4c.create_network_from_networkx(network)
# Out:
# Applying default style...
# In commands_post(): No network views selected.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/py4cytoscape/commands.py in commands_post(cmd, base_url)
#     389         r = _do_request('POST', post_url, json=post_body, headers=headers, base_url=base_url)
# --> 390         r.raise_for_status()
#     391         res = json.loads(r.text)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/models.py in raise_for_status(self)
#     942         if http_error_msg:
# --> 943             raise HTTPError(http_error_msg, response=self)
#     944
#
# HTTPError: 500 Server Error: Internal Server Error for url: http://127.0.0.1:1234/v1/commands/vizmap/apply
#
# During handling of the above exception, another exception occurred:
#
# CyError                                   Traceback (most recent call last)
# ...

# %%
p4c.notebook_export_show_image(filename='interactome')

# %%
repr(dir(p4c))

# %%
# %connect_info
